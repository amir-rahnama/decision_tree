# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import OneHotEncoder
from decision_tree import DT

# %% [markdown]
# ### Regression

# %%
training_data_reg = pd.DataFrame([
    ['Green', 3, 0.7],
    ['Green', 1, 0.2],
    ['Red', 1, 0.5],
    ['Red', 4, 0.1],
    ['Yellow', 4, 0.6],
], columns=['color', 'size', 'label'] )

data_reg = training_data_reg.iloc[:, 0:-1]
labels_reg = training_data_reg.iloc[:, -1]
n = pd.get_dummies(data_reg.iloc[:,0])
data_reg = data_reg.drop(columns=['color'])
train_data_reg = pd.concat([n, data_reg], axis=1)

# %%
new_data_reg = pd.concat([train_data_reg, labels_reg], axis=1)

# %%
dt = DT(mode='regression', data=new_data_reg, max_depth=1)
dt.fit()

# %%
dt.predict(new_data_reg)
# Out:
# array([0.5, 0.5, 0.3, 0.3, 0.5])

# %%
dot = dt.draw()
dot

# %% [markdown]
# ### Classification

# %%
training_data_cl = pd.DataFrame([
    ['Green', 3, 'Apple'],
    ['Yellow', 3, 'Apple'],
    ['Red', 1, 'Grape'],
    ['Red', 1, 'Grape'],
    ['Yellow', 3, 'Lemon'],
], columns=['color', 'size', 'label'] )

class_names = training_data_cl.iloc[:, 2].unique()

data_cl = training_data_cl.iloc[:, 0:-1]
labels_cl = training_data_cl.iloc[:, -1]

n_cl = pd.get_dummies(data_cl.iloc[:,0])

data_cl = data_cl.drop(columns=['color'])
train_data_cl = pd.concat([n_cl, data_cl], axis=1)

new_data_cl = pd.concat([train_data_cl, labels_cl], axis=1)

# %%
dt_cl = DT(mode='classification', data=new_data_cl, max_depth=3, class_names=class_names)
dt_cl.fit()

# %%
dt_cl.draw()

# %% [markdown]
# ### Boosting

# %%
bt_regression.predict()
# Out:
# new_data <class 'pandas.core.frame.DataFrame'>    Green  Red  Yellow  size  label
# 0      1    0       0     3   0.28
# 1      1    0       0     1  -0.22
# 2      0    1       0     1   0.08
# 3      0    1       0     4  -0.32
# 4      0    0       1     4   0.18
# new_data <class 'pandas.core.frame.DataFrame'>    Green  Red  Yellow  size  label
# 0      1    0       0     3    0.2
# 1      1    0       0     1   -0.3
# 2      0    1       0     1    0.2
# 3      0    1       0     4   -0.2
# 4      0    0       1     4    0.1
# new_data <class 'pandas.core.frame.DataFrame'>    Green  Red  Yellow  size     label
# 0      1    0       0     3  0.250000
# 1      1    0       0     1 -0.250000
# 2      0    1       0     1  0.166667
# 3      0    1       0     4 -0.233333
# 4      0    0       1     4  0.066667
# array([-0., -0., -0., -0.,  0.])

# %%
bt_regression.trees[0].draw()

# %%
# Out:
# new_data <class 'pandas.core.frame.DataFrame'>    Blue  Green  Likes PopCorn  Age     Label
# 0     1      0              1   12  0.306853
# 1     0      1              1   87  0.306853
# 2     1      0              0   44 -0.693147
# new_data <class 'pandas.core.frame.DataFrame'>    Blue  Green  Likes PopCorn  Age  \
# 0     1      0              1   12
# 1     0      1              1   87
# 2     1      0              0   44
#
#                                            Label
# 0  0    0.0
# 1    0.0
# Name: Label, dtype: float64
# 1  0    0.0
# 1    0.0
# Name: Label, dtype: float64
# 2           2    0.0
# Name: Label, dtype: float64
# <ipython-input-233-afa8ab1d090d>:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(pred_result)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-266-a71529144d37> in <module>
# ----> 1 bt_classification.predict()
#
# <ipython-input-257-6149d294b2e3> in predict(self)
#      44             else:
#      45                 dt = DT(mode='regression', data=new_data, max_depth=self.max_depth, method='non_average')
# ---> 46                 dt.fit()
#      47
#      48                 pred = dt.predict(new_data)
#
# <ipython-input-233-afa8ab1d090d> in fit(self)
#      98     def fit(self):
#      99         node_id = self.counter()
# --> 100         return self.grow_tree(self.data, node_id)
#     101
#     102
#
# <ipython-input-233-afa8ab1d090d> in grow_tree(self, data, node_id)
#      77
#      78     def grow_tree(self, data, node_id):
# ---> 79         best_gain, best_filter = self.find_split(data)
#      80
#      81         true_rows, false_rows = self.partition(data, best_filter['feature'], best_filter['value'])
#
# <ipython-input-233-afa8ab1d090d> in find_split(self, data)
#      56     def find_split(self, data):
#      57         best_gain = 0
# ---> 58         current_cost = self.cost(data)
#      59         num_features = data.shape[1] - 1
#      60
#
# <ipython-input-233-afa8ab1d090d> in cost(self, data)
#      34             return self.gini(data)
#      35         else:
# ---> 36             return self.mse(data)
#      37
#      38
#
# <ipython-input-233-afa8ab1d090d> in mse(self, data)
#      27     def mse(self, data):
#      28         y = data.iloc[:, -1]
# ---> 29         avg_pred = np.mean(y)
#      30         return np.sum((y - avg_pred)**2)
#      31
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3368             pass
#    3369         else:
# -> 3370             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3371
#    3372     return _methods._mean(a, axis=axis, dtype=dtype,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     561         dtype_count = dtype
#     562     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 563     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     564
#     565     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1425     elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1426         try:
# -> 1427             x = float(x)
#    1428         except ValueError:
#    1429             # e.g. "1+1j" or "foo"
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in wrapper(self)
#     127         if len(self) == 1:
#     128             return converter(self.iloc[0])
# --> 129         raise TypeError(f"cannot convert the series to {converter}")
#     130
#     131     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'float'>

# %%
class_data_new
# Out:
#    Blue  Green  Likes PopCorn  Age  Label
# 0     1      0              1   12      1
# 1     0      1              1   87      1
# 2     1      0              0   44      0
